# %% [markdown]
# <a href="https://colab.research.google.com/github/druzyna-pierscienia/Big-Data-i-hurtownie-danych-II/blob/Colab/Big_data_i_hurtownie_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
url = 'https://api.data.gov/ed/collegescorecard/v1/schools.json?fields=2021.cost.roomboard.oncampus,2021.admissions.sat_scores.average.overall,id,school.name,2021.student.size&api_key=QK0fIcoYWkQjXaHfwM4QJkhU565cxfE5pLzWByRn&per_page=30000'
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=4))
else:
    print("Błąd pobierania danych:", response.status_code)
# Out:
# {
#     "metadata": {
#         "page": 0,
#         "total": 6484,
#         "per_page": 100
#     },
#     "results": [
#         {
#             "2021.cost.roomboard.oncampus": 9520,
#             "2021.admissions.sat_scores.average.overall": 954,
#             "2021.student.size": 5098,
#             "school.name": "Alabama A & M University",
#             "id": 100654
#         },
#         {
#             "2021.cost.roomboard.oncampus": 12307,
#             "2021.admissions.sat_scores.average.overall": 1266,
#             "2021.student.size": 13284,
#             "school.name": "University of Alabama at Birmingham",
#             "id": 100663
#         },
#         {
#             "2021.cost.roomboard.oncampus": 0,
#             "2021.admissions.sat_scores.average.overall": null,
#             "2021.student.size": 251,
#             "school.name": "Amridge University",
#             "id": 100690
#         },
#         {
#             "2021.cost.roomboard.oncampus": 10764,
# ...
